# %%
# Dependencies
import requests
import json
import os
import pandas as pd
import numpy as np
from pprint import pprint

# %%
import requests
import json

Base_Url="http://api.worldbank.org/v2/country/"
Country = 'co'
url = Base_Url + Country + '?format=json'

#indicators
#https://datahelpdesk.worldbank.org/knowledgebase/articles/201175-how-does-the-world-bank-code-its-indicators
# literacy rate: SE.ADT.LITR.ZS
#population: SP.POP.TOTL
#llefe expectancy: SP.DYN.LE00.IN
#gdp per capita :NY.GDP.PCAP.CD

#full syntax
response = requests.get('http://api.worldbank.org/v2/country/co/indicator/SE.ADT.LITR.ZS?date=2016&format=json')
#http://api.worldbank.org/v2/country/br/indicator/NY.GDP.MKTP.CD?date=2006
#('http://api.worldbank.org/v2/indicator/NY.GDP.MKTP.CD?format=json')
#('http://api.worldbank.org/v2/indicator?format=json')
#('http://api.worldbank.org/v2/indicators/NY.GDP.MKTP.CD?format=json')
#('http://api.worldbank.org/v2/topic?format=json')
#http://api.worldbank.org/v2/country/all/indicator/SP.POP.TOTL?date=2000:2001

response_json = response.json()
#Population = response_json[1][0]['value']
#Population
pprint(response_json)


#pprint(requests.get(url))
# Out:
# [{'lastupdated': '2019-03-21',
#   'page': 1,
#   'pages': 1,
#   'per_page': 50,
#   'sourceid': '2',
#   'total': 1},
#  [{'country': {'id': 'CO', 'value': 'Colombia'},
#    'countryiso3code': 'COL',
#    'date': '2016',
#    'decimal': 0,
#    'indicator': {'id': 'SE.ADT.LITR.ZS',
#                  'value': 'Literacy rate, adult total (% of people ages 15 and '
#                           'above)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 94.65385}]]

# %%
import spotipy
#from spotipy.oauth2 import SpotifyClientCredentials
client_id='a7c49e4b412941709f9ab03c700d61b8'
client_secret='3e46f9fc9338407cb1d0b6a915fb6d4d'

from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
# Out:
#    1 spotify:playlist:37i9dQZF1DXcBWIGoYBM5M Today's Top Hits
#    2 spotify:playlist:37i9dQZF1DX0XUsuxWHRQd RapCaviar
#    3 spotify:playlist:37i9dQZF1DX4dyzvuaRJ0n mint
#    4 spotify:playlist:37i9dQZF1DX4SBhb3fqCJd Are & Be
#    5 spotify:playlist:37i9dQZF1DXcF6B6QPhFDv Rock This
#    6 spotify:playlist:37i9dQZF1DX1lVhptIYRda Hot Country
#    7 spotify:playlist:37i9dQZF1DX10zKzsJ2jva ¡Viva Latino!
#    8 spotify:playlist:37i9dQZF1DX4JAvHpjipBk New Music Friday
#    9 spotify:playlist:37i9dQZF1DX4E3UdUs7fUx Afternoon Acoustic
#   10 spotify:playlist:37i9dQZF1DX4sWSpwq3LiO Peaceful Piano
#   11 spotify:playlist:37i9dQZF1DWYV7OOaGhoH0 Roots Rising
#   12 spotify:playlist:5JdIoXkjfuyWmDdDnznmq1 Lost In Austin: Country Music from SXSW
#   13 spotify:playlist:37i9dQZF1DX5PuwKY2VZBZ SXSW: HipHopUpNext
#   14 spotify:playlist:37i9dQZF1DWXJfnUiYjUKT New Music Friday
#   15 spotify:playlist:4HghCZXykAY0kdRqJipQJd Music Inspired By Mogul
# ...

# %%
import spotipy
#from spotipy.oauth2 import SpotifyClientCredentials
client_id='a7c49e4b412941709f9ab03c700d61b8'
client_secret='3e46f9fc9338407cb1d0b6a915fb6d4d'

from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


tid = 'spotify:track:0FWhGmPVxLI6jOVF0wjALa'


analysis = sp.audio_analysis(tid)
fearure = sp.audio_features(tid)




print(json.dumps(fearure, indent=4))
#print ("analysis retrieved in %.2f seconds" % (delta,))
# Out:
# [
#     {
#         "danceability": 0.9,
#         "energy": 0.845,
#         "key": 11,
#         "loudness": -7.306,
#         "mode": 0,
#         "speechiness": 0.257,
#         "acousticness": 0.465,
#         "instrumentalness": 0,
#         "liveness": 0.0724,
#         "valence": 0.914,
#         "tempo": 111.187,
#         "type": "audio_features",
#         "id": "0FWhGmPVxLI6jOVF0wjALa",
#         "uri": "spotify:track:0FWhGmPVxLI6jOVF0wjALa",
#         "track_href": "https://api.spotify.com/v1/tracks/0FWhGmPVxLI6jOVF0wjALa",
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/0FWhGmPVxLI6jOVF0wjALa",
#         "duration_ms": 427360,
#         "time_signature": 4
#     }
# ]

# %%
import spotipy
#from spotipy.oauth2 import SpotifyClientCredentials
client_id='a7c49e4b412941709f9ab03c700d61b8'
client_secret='3e46f9fc9338407cb1d0b6a915fb6d4d'

from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)


#artistName='chic'
trackName='rappers delight'
#q= String.init(format:"artist:%@ track:%@",artistName,trackName)


search=sp.search(q="rappers delight", type="track", limit=10)
searchdetail=search["tracks"]["items"][0]["uri"]
#searchdetail=search["tracks"]["items"][0]
print(json.dumps(searchdetail, indent=2))
# Out:
# "spotify:track:0FWhGmPVxLI6jOVF0wjALa"
